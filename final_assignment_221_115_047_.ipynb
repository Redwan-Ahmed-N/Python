# %% [markdown]
# #Name: Redwan Ahmed
# ### ID: 221-115-047

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #Short Questions (1 Mark)

# %% [markdown]
#  1. What code would you use to combine two DataFrames(df1, df2) along the columns?
# 0Ans:df=pd.concat([df1,df2],axis=1)

# %% [markdown]
# 2. Create a DataFrame from a dictionary with two columns, 'Name' and 'Age', where 'Name' contains ["Alice", "Bob"] and 'Age' contains [25, 30].
#
#   ans: df = pd.DataFrame({
#     'Name':['Alice', 'Bob'],
#     'Age':[25, 30]
#     })

# %% [markdown]
# 3. What function would you use to display the first five rows of a DataFrame, and why is it useful?
#
#   ans: df.head()

# %% [markdown]
# 4. How can you check for missing values in a DataFrame?
#
#   ans: df.isnull()

# %% [markdown]
# 5. Describe how to filter rows in a DataFrame based on a condition in one of its columns.
#
#   ans: filtered_df = df[df['column_name'] > value]

# %% [markdown]
# 5. What method would you use to remove duplicate rows in a DataFrame?
#
#   ans: df.drop_duplicates()

# %% [markdown]
# 6. What is the purpose of the merge function in Pandas?
#
#   ans: Joining dataframes based on the common columns.

# %% [markdown]
# 7. How can you sort a DataFrame by multiple columns?
#
#   ans: using df.sort_values(by=['col1_name','col2_name']) command.

# %% [markdown]
# 8. How do Pandas represent missing data in numeric and non-numeric data types?
#
#   ans:
#
#       numeric: np.nan (not a number)
#
#       non-numeric: None

# %% [markdown]
# 9. Write code to filter a DataFrame df to display only rows where the 'Age' column is greater than 25.
#   ans: filtered_df = df[df['Age'] > 25]

# %% [markdown]
# 10. What does the fillna() function do, and why is it useful? Provide a code example.
#
#   ans: the fillna() function used for fill missing value by a number
#
#   ex: df.fillna(0)

# %% [markdown]
#   11. How can you capitalize all entries in a 'City' column of a DataFrame using a vectorized string operation?
#
#  df['City'] = df['City'].str.capitalize()

# %% [markdown]
# 11.  Describe how the dropna() method works in Pandas.
#
#   ans: removes missing value with its row

# %% [markdown]
# 12. Describe 'ffill' or 'bfill' method.
#
#   ans: ffill : forward fill ,  bfill : backward fill

# %% [markdown]
# 13. Write a code using Pandas to replace all NaN values in a DataFrame with zeros.
#
#   ans: df.fillna(0)

# %% [markdown]
# 14. What is the purpose of the pd.concat() function in Pandas?
#
#   ans: concatenates multiple DataFrames along specified axis

# %% [markdown]
# 15. Write a Pandas command to find the maximum value in the 'Sales' column of a DataFrame ‘df’.
#
#   ans: df['Sales'].max()

# %% [markdown]
# 16. What parameter would you use in pd.concat() to ignore index values and create a new default integer index?
#
#   ans: ignore_index = True

# %% [markdown]
# 17. Describe how to concatenate DataFrames df1 and df2 along columns.
#
#   ans: pd.concat([df1, df2], axis=1)

# %% [markdown]
# 18. How can you perform an inner join using pd.concat()?
#
#   ans: pd.concat([df1, df2], join='inner')

# %% [markdown]
# 19. How would you merge two DataFrames, df1 and df2, based on a common column 'ID'?
#
#   ans: pd.merge(df1, df2, on='ID')

# %% [markdown]
# 20. What command is used to save a plot to a file in Matplotlib?
#
#   ans: plt.savefig('filename.png')

# %% [markdown]
# 21. How can you save a plot as a PNG file named plot_image.png?
#
#   ans: plt.savefig('plot_image.png')

# %% [markdown]
# 22. Which argument can you use in plt.savefig to save a plot with a transparent background?
#
#   ans: plt.savefig('plot_image.png', transparent=True)

# %% [markdown]
# 23. What function would you use in Pandas to calculate the average of a DataFrame’s column?
#
#   ans: df['Redwan'].mean()

# %% [markdown]
# 24. Write the command to plot the points (1, 2), (2, 4), (3, 6) as a simple line plot.
#
#   ans: plt.plot([1,2,3],[2,4,6])

# %% [markdown]
# 25. How can you display a line plot after plotting it with plt.plot()?
#
#   ans: plt.show()

# %% [markdown]
# 26. What does the command plt.plot(x, y, 'o-') do differently from plt.plot(x, y)?
#
#   ans: plt.plot(x, y, 'o-') will create a line plot with circular markers on each point, while plt.plot(x, y) will create a plain line plot without marker.

# %% [markdown]
# 27. How can you change the line color to red in a line plot?
#
#   ans: plt.plot(x, y, color='red')

# %% [markdown]
# 28. Which argument in plt.plot() allows you to set the line style as dashed?
#
#   ans: linestyle = '--'

# %% [markdown]
# 29. Write a command to create a blue dotted line plot using x and y data.
#
#   ans: plt.plot(x, y, color='blue', linestyle=':')

# %% [markdown]
# 30. How can you make the line width thicker in a plot?
#
#   ans: plt.plot(x, y, linewidth=2)

# %% [markdown]
# 31. What command is used to set the x-axis range from 0 to 10 in a plot?
#
#   ans: plt.xlim(0, 10)

# %% [markdown]
# 32. How can you limit the y-axis between -5 and 5 in a plot?
#
#   ans: plt.ylim(0, 8)

# %% [markdown]
# 33. Which command is used to add a title to a plot?
#
#   ans: plt.title('Title dewwwww ree mona😀')

# %% [markdown]
# 35. How do you add a legend to a plot?
#
#   ans: plt.legend()

# %% [markdown]
# #**Broad Questions**

# %% [markdown]
# Question 3:
# You have temperature data (in degrees Celsius) for a city across seven days:
# days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
# temperatures = [22, 25, 23, 20, 19, 21, 24]
# 1. Create a Pandas Series from the data with days as index and temperatures as values.
# 2. Find the highest and lowest temperatures of the week.
# 3. Calculate the average temperature of the week and add it as a new entry to the Series
# under the label 'Average'.
# 4. Plot the temperatures for each day as a line plot with markers for each data point.

# %%
#1

import pandas as pd
import matplotlib.pyplot as plt
days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
temperatures = [22, 25, 23, 20, 19, 21, 24]
series = pd.Series(temperatures, index=days)
series
# Out:
# Mon    22
# Tue    25
# Wed    23
# Thu    20
# Fri    19
# Sat    21
# Sun    24
# dtype: int64

# %%
#2
series.max()
# Out:
# 25

# %%
#3
average = series.mean()
average
series['Average'] = average
series
# Out:
# Mon        22.0
# Tue        25.0
# Wed        23.0
# Thu        20.0
# Fri        19.0
# Sat        21.0
# Sun        24.0
# Average    22.0
# dtype: float64

# %%
#4
series.plot(kind='line', marker='o')
plt.xlabel('Days')
plt.ylabel('Temperatures')
plt.title('Temperatures for Each Day')
plt.show()

# %% [markdown]
# Question 4:
# You have monthly sales data for different products in a store, represented as follows:
# data = {'Product': ['Laptop', 'Tablet', 'Smartphone', 'Headphones', 'Laptop'],
# 'Month': ['Jan', 'Feb', 'Mar', 'Jan', 'Feb'],
# 'Sales': [1500, 1200, 1300, 500, 1600]}
# 1. Create a DataFrame from the data.
# 2. Group the data by 'Product' and calculate the total 'Sales' for each product.
# 3. Calculate the average 'Sales' per month.
# 4. Filter the DataFrame to show only rows where the sales are above 1000.
# 5. Plot a bar chart of total sales per product.

# %%
#1
data = {'Product': ['Laptop', 'Tablet', 'Smartphone', 'Headphones', 'Laptop'], 'Month': ['Jan', 'Feb', 'Mar', 'Jan', 'Feb'], 'Sales': [1500, 1200, 1300, 500, 1600]}
df=pd.DataFrame(data)
df
# Out:
#       Product Month  Sales
# 0      Laptop   Jan   1500
# 1      Tablet   Feb   1200
# 2  Smartphone   Mar   1300
# 3  Headphones   Jan    500
# 4      Laptop   Feb   1600

# %%
#1
data = {'Product': ['Laptop', 'Tablet', 'Smartphone', 'Headphones', 'Laptop'], 'Month': ['Jan', 'Feb', 'Mar', 'Jan', 'Feb'], 'Sales': [1500, 1200, 1300, 500, 1600]}
df=pd.DataFrame(data)
df
# Out:
#       Product Month  Sales
# 0      Laptop   Jan   1500
# 1      Tablet   Feb   1200
# 2  Smartphone   Mar   1300
# 3  Headphones   Jan    500
# 4      Laptop   Feb   1600

# %%
#3
df.groupby('Month')['Sales'].mean()
# Out:
# Month
# Feb    1400.0
# Jan    1000.0
# Mar    1300.0
# Name: Sales, dtype: float64

# %%
#4
filter_salaes =df[df['Sales']>1000]
filter_salaes
# Out:
#       Product Month  Sales
# 0      Laptop   Jan   1500
# 1      Tablet   Feb   1200
# 2  Smartphone   Mar   1300
# 4      Laptop   Feb   1600

# %%
#5
total_sales = df.groupby('Product')['Sales'].sum()
total_sales.plot(kind='bar')
plt.xlabel('Product')
plt.ylabel('Total Sales')
plt.title('Total Sales per Product')
plt.show()

# %% [markdown]
# Question 6: Consider a dataset that tracks employee information, including their names,
# departments, and years of experience. Some of the values for 'Years of Experience' are missing.
# The data is given as follows:
#
# import pandas as pd
# # Employee data with missing values
# data = {
# 'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
# 'Department': ['HR', 'IT', 'Finance', None, 'Marketing'],
# 'Years of Experience': [5, None, 8, 6, None]
# }
# employees_df = pd.DataFrame(data)
# 1. Write code to detect the missing values in each column.
# 2. Drop rows where the 'Department' data is missing.
# 3. Fill in missing values in the 'Years of Experience' column with the average years of
# experience from the available data.

# %%
#1
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'], 'Department': ['HR', 'IT', 'Finance', None, 'Marketing'], 'Years of Experience': [5, None, 8, 6, None]}
employees_df = pd.DataFrame(data)
employees_df
# Out:
#       Name Department  Years of Experience
# 0    Alice         HR                  5.0
# 1      Bob         IT                  NaN
# 2  Charlie    Finance                  8.0
# 3    David       None                  6.0
# 4      Eva  Marketing                  NaN

# %%
#2
drop_missing_department = employees_df.dropna(subset=['Department'])
drop_missing_department
# Out:
#       Name Department  Years of Experience
# 0    Alice         HR                  5.0
# 1      Bob         IT                  NaN
# 2  Charlie    Finance                  8.0
# 4      Eva  Marketing                  NaN

# %%
#3
average_experience = employees_df['Years of Experience'].mean()
employees_df['Years of Experience'].fillna(average_experience, inplace=True)
employees_df
# Out:
# <ipython-input-13-486785269139>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   employees_df['Years of Experience'].fillna(average_experience, inplace=True)
#       Name Department  Years of Experience
# 0    Alice         HR             5.000000
# 1      Bob         IT             6.333333
# 2  Charlie    Finance             8.000000
# 3    David       None             6.000000
# 4      Eva  Marketing             6.333333

# %% [markdown]
# Question 7:
# You have data on books in a library:
# library_data = {
# 'Title': ['Introduction to Python', 'Advanced Python', 'Machine Learning Basics', 'Deep
# Learning with Python'],
# 'Genre': ['Programming', 'Programming', 'AI', 'AI'],
# 'Copies': [10, 5, 8, 12]
# }
# 1. Create a DataFrame from the data. Then use a vectorized string operation to split each
# title and keep only the first word in a new column.
# 2. Group by 'Genre' and calculate the total copies for each genre.
# 3. Filter the DataFrame to display only books with less than 12 copies.
# 4. Plot a bar chart of the total copies per genre.

# %%
library_data = {'Title': ['Introduction to Python', 'Advanced Python', 'Machine Learning Basics', 'Deep Learning with Python'], 'Genre': ['Programming', 'Programming', 'AI', 'AI'], 'Copies': [10, 5, 8, 12]}
df = pd.DataFrame(library_data)
df
# Out:
#                        Title        Genre  Copies
# 0     Introduction to Python  Programming      10
# 1            Advanced Python  Programming       5
# 2    Machine Learning Basics           AI       8
# 3  Deep Learning with Python           AI      12

# %%
df['First Word'] = df['Title'].str.split().str[0]
df
# Out:
#                        Title        Genre  Copies    First Word
# 0     Introduction to Python  Programming      10  Introduction
# 1            Advanced Python  Programming       5      Advanced
# 2    Machine Learning Basics           AI       8       Machine
# 3  Deep Learning with Python           AI      12          Deep

# %%
#2
df.groupby('Genre')['Copies'].sum()
# Out:
# Genre
# AI             20
# Programming    15
# Name: Copies, dtype: int64

# %%
#3
df[df['Copies']<12]
# Out:
#                      Title        Genre  Copies    First Word
# 0   Introduction to Python  Programming      10  Introduction
# 1          Advanced Python  Programming       5      Advanced
# 2  Machine Learning Basics           AI       8       Machine

# %%
#4
total_copies = df.groupby('Genre')['Copies'].sum()
total_copies.plot(kind='bar')
plt.xlabel('Genre')
plt.ylabel('Total Copies')
plt.title('Total Copies per Genre')
plt.show()

# %% [markdown]
# Question 8:
# Combine Datasets with concat and append
# ● Given two small DataFrames with columns for name, age, and score, use pd.concat to
# combine these datasets.
#
# Concatenate NumPy Arrays
# ● Create two 1-dimensional NumPy arrays: array1 with values [1, 2, 3] and array2 with
# values [4, 5, 6].
#
# ● Use np.concatenate to combine them into a single array.
#
# Concatenate with Different Join Types
# ● Create two DataFrames: df1 with columns id, name, and score, and df2 with columns id,
# age, and city.
#
# ● Use pd.concat with both inner and outer join types to combine these DataFrames based
# on the id column.
#
# Merge DataFrames
# ● Given df1 and df2 from step 3, use pd.merge() to combine them on the id column.
#
# Groupby and Aggregate Data
# ● Using a DataFrame representing sales data (columns: product, region, sales, and date),
# group the data by region and calculate:
#
# ○ The total sales for each region.
# ○ The average sales for each product.
#
# Query with DataFrame.query and eval
# ● Using the sales data DataFrame, use query to find rows where sales are greater than a specified threshold (e.g., 1000).
# ● Use eval to calculate the total sales of all products in a specific region.

# %% [markdown]
# #Question 9
#
#   You have been given data about a small grocery store's sales figures across different categories. The data shows the number of units sold per item category, average unit price, and customer ratings. Use this data to create visualizations that represent various aspects of the sales and customer ratings.
#
#
# ```
# # Sales data
# categories = ['Fruits', 'Vegetables', 'Dairy', 'Bakery', 'Snacks']
# units_sold = [120, 200, 150, 90, 130]
# avg_price = [2.5, 1.5, 2.0, 1.8, 3.0]  # in dollars
# customer_ratings = [4.5, 4.2, 4.0, 3.8, 4.1]
# ```
# Using the data above, complete the following tasks:
#
#   1. **Bar Plot:** Plot a bar chart showing units sold for each category. Add a title, x-axis label ("Categories"), and y-axis label ("Units Sold"). Also, include a legend.
#
#   2.**Scatter Plot:** Create a scatter plot of units_sold (on the x-axis) vs. avg_price (on the y-axis). Add a title and labels for both axes.
#
#   3. **Histogram:** Plot a histogram of customer_ratings to see the distribution of ratings. Add a title and label the x-axis as "Customer Ratings" and the y-axis as "Frequency".
#
#   4. **Pie Chart:** Create a pie chart to show the percentage of units sold by category. Add a title and a legend showing the category names.
#
#   5. **Box Plot:** Plot a box plot to visualize the spread and central tendency of customer_ratings. Add a title.
#
# Use appropriate colors, and ensure each plot has a title and labeled axes (where applicable).

# %%
categories = ['Fruits', 'Vegetables', 'Dairy', 'Bakery', 'Snacks']
units_sold = [120, 200, 150, 90, 130]
avg_price = [2.5, 1.5, 2.0, 1.8, 3.0]  # in dollars
customer_ratings = [4.5, 4.2, 4.0, 3.8, 4.1]

# %%
Colors = ['skyblue', 'lightgreen', '#FFCC99', 'lightcoral', 'lightpink']

# %%
#1
bars = plt.bar(categories, units_sold, color=Colors)
plt.title('Bar Plot')
plt.xlabel('Categories')
plt.ylabel('Units Sold')

plt.legend(bars, categories)

plt.show()

# %%
#2
plt.scatter(units_sold, avg_price, color='red', marker='s')
plt.title('Scatter Plot')
plt.xlabel('Units Sold')
plt.ylabel('Average Price')
plt.show()

# %%
#3
plt.hist(customer_ratings, color='#F49097')
plt.title('Histogram')
plt.xlabel('Customer Ratings')
plt.ylabel('Frequency')
plt.show()

# %%
#4
plt.pie(units_sold, labels=categories, autopct='%1.2f%%', colors = Colors)
plt.title('Pie Chart')
plt.show()

# %%
#5
plt.boxplot(customer_ratings, vert=False)
plt.title('Box Plot')
plt.show()
